# %%
# %run main.py
# Out:
# https://www.google.com/search?q=site:finance&start=0&tbs=qdr:d
# https://www.google.com/search?q=site:finance&start=10&tbs=qdr:d
# https://www.google.com/search?q=site:finance&start=20&tbs=qdr:d
# https://www.google.com/search?q=site:finance&start=30&tbs=qdr:d
# https://www.google.com/search?q=site:finance&start=40&tbs=qdr:d
# https://www.google.com/search?q=site:finance&start=50&tbs=qdr:d

# %%
tb
# Out:
#                     .finance
# 0            www.icm.finance
# 1              yahoo.finance
# 2        www.abcnews.finance
# 3        www.gordian.finance
# 4       www.theworld.finance
# 5            bscgems.finance
# 6               thai.finance
# 7            coronis.finance
# 8               yffd.finance
# 9               yffd.finance
# 10         ed.simtec.finance
# 11         nerdlings.finance
# 12       pancakeswap.finance
# 13        www.octans.finance
# 14             slick.finance
# 15           harvets.finance
# 16          pubs.pub.finance
# 17          piranhas.finance
# 18          piranhas.finance
# 19      www.irmscher.finance
# 20          squirrel.finance
# 21            outlet.finance
# 22        www.shroom.finance
# 23           incipit.finance
# 24     www.powerpool.finance
# 25           pimenta.finance
# 26         mushrooms.finance
# 27              cfxo.finance
# 28   alpha.circulate.finance
# 29          www.zzz2.finance
# 30        www.triton.finance
# ...

# %%
tb.drop_duplicates()
# Out:
#                     .finance
# 0            www.icm.finance
# 1              yahoo.finance
# 2        www.abcnews.finance
# 3        www.gordian.finance
# 4       www.theworld.finance
# 5            bscgems.finance
# 6               thai.finance
# 7            coronis.finance
# 8               yffd.finance
# 10         ed.simtec.finance
# 11         nerdlings.finance
# 12       pancakeswap.finance
# 13        www.octans.finance
# 14             slick.finance
# 15           harvets.finance
# 16          pubs.pub.finance
# 17          piranhas.finance
# 19      www.irmscher.finance
# 20          squirrel.finance
# 21            outlet.finance
# 22        www.shroom.finance
# 23           incipit.finance
# 24     www.powerpool.finance
# 25           pimenta.finance
# 26         mushrooms.finance
# 27              cfxo.finance
# 28   alpha.circulate.finance
# 29          www.zzz2.finance
# 30        www.triton.finance
# 31            glitch.finance
# 32              yfiy.finance
# ...

# %%
tb.index += 1
tb.drop_duplicates()
# Out:
#                     .finance
# 1            www.icm.finance
# 2              yahoo.finance
# 3        www.abcnews.finance
# 4        www.gordian.finance
# 5       www.theworld.finance
# 6            bscgems.finance
# 7               thai.finance
# 8            coronis.finance
# 9               yffd.finance
# 11         ed.simtec.finance
# 12         nerdlings.finance
# 13       pancakeswap.finance
# 14        www.octans.finance
# 15             slick.finance
# 16           harvets.finance
# 17          pubs.pub.finance
# 18          piranhas.finance
# 20      www.irmscher.finance
# 21          squirrel.finance
# 22            outlet.finance
# 23        www.shroom.finance
# 24           incipit.finance
# 25     www.powerpool.finance
# 26           pimenta.finance
# 27         mushrooms.finance
# 28              cfxo.finance
# 29   alpha.circulate.finance
# 30          www.zzz2.finance
# 31        www.triton.finance
# 32            glitch.finance
# 33              yfiy.finance
# ...
